# %% [markdown]
# <a href="https://colab.research.google.com/github/NyusenKyusai/18018535_DataAnalytics/blob/main/TestingCrimesDataToChooseCorrectDateRange.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Calling in the crimes csv to see what part of the data is usable and stable

# %%
crimes <- read.csv("https://raw.githubusercontent.com/NyusenKyusai/18018535_DataAnalytics/main/chicago_crime.csv", stringsAsFactors = TRUE)

# %% [markdown]
# Seeing the first 6 entries of the csv

# %%
head(crimes)
# Out:
#   crime_date NUM_CRIMES
# 1 2001-01-01 1822
# 2 2001-01-02 1143
# 3 2001-01-03 1151
# 4 2001-01-04 1166
# 5 2001-01-05 1267
# 6 2001-01-06 1290

# %% [markdown]
# Getting a summary of the crimes csv

# %%
summary(crimes)
# Out:
#       crime_date     NUM_CRIMES
#  2001-01-01:   1   Min.   : 320.0
#  2001-01-02:   1   1st Qu.: 732.0
#  2001-01-03:   1   Median : 939.0
#  2001-01-04:   1   Mean   : 968.3
#  2001-01-05:   1   3rd Qu.:1220.0
#  2001-01-06:   1   Max.   :2031.0
#  (Other)   :7763

# %% [markdown]
# Plotting the number of crimes vs the day of the year. The time period of 2015 to 2019 is the most stable period, making it the best period to use

# %%
plot(crimes$crime_date, crimes$NUM_CRIMES, main = "Number of crimes vs. Day of the year")
# Out:
# Plot with title “Number of crimes vs. Day of the year”

# %% [markdown]
# Reading the csv file for then the data is cut into the 2015 and 2019 range

# %%
cutCrimes <- read.csv("https://raw.githubusercontent.com/NyusenKyusai/18018535_DataAnalytics/main/chicago_crime-2015-2019.csv", stringsAsFactors = TRUE)

# %%
head(cutCrimes)
# Out:
#   crime_date NUM_CRIMES
# 1 2015-01-01 1234
# 2 2015-01-02  674
# 3 2015-01-03  648
# 4 2015-01-04  514
# 5 2015-01-05  523
# 6 2015-01-06  503

# %%
summary(cutCrimes)
# Out:
#       crime_date     NUM_CRIMES
#  2015-01-01:   1   Min.   : 341.0
#  2015-01-02:   1   1st Qu.: 678.0
#  2015-01-03:   1   Median : 734.0
#  2015-01-04:   1   Mean   : 729.9
#  2015-01-05:   1   3rd Qu.: 788.0
#  2015-01-06:   1   Max.   :1234.0
#  (Other)   :1820

# %%
plot(cutCrimes$crime_date, cutCrimes$NUM_CRIMES, main = "Number of crimes vs. Day of the year")
# Out:
# Plot with title “Number of crimes vs. Day of the year”

# %%
cutWeather <- read.csv("https://raw.githubusercontent.com/NyusenKyusai/18018535_DataAnalytics/main/chicago_weather-2015-2019.csv", stringsAsFactors = TRUE)

# %%
head(cutWeather)
# Out:
#   date       year mo da temp dewp slp    visib wdsp mxpsd gust  max  min  prcp
# 1 2015-01-01 2015 1  1  19.9  6.0 1019.3 10.0  13.7 18.1   27.0 32.0  3.9 0.00
# 2 2015-01-02 2015 1  2  25.7 16.0 1023.3 10.0   5.1 14.0   19.0 34.0 14.0 0.00
# 3 2015-01-03 2015 1  3  31.5 27.0 1017.7  5.2   4.6  8.0  999.9 34.0 15.1 0.09
# 4 2015-01-04 2015 1  4  29.0 26.1 1012.9  3.2  10.3 22.0   27.0 34.0 12.9 0.57
# 5 2015-01-05 2015 1  5   2.2 -7.4 1034.9 10.0  12.4 18.1   24.1 12.9 -2.9 0.04
# 6 2015-01-06 2015 1  6   5.3 -0.9 1028.6  7.4   9.0 20.0   25.1 10.0 -5.1 0.16
#   sndp  fog
# 1 999.9 0
# 2 999.9 0
# 3 999.9 0
# 4   2.0 1
# 5   2.0 0
# 6   3.1 0

# %%
summary(cutWeather)
# Out:
#          date           year            mo               da
#  2015-01-01:   1   Min.   :2015   Min.   : 1.000   Min.   : 1.00
#  2015-01-02:   1   1st Qu.:2016   1st Qu.: 4.000   1st Qu.: 8.00
#  2015-01-03:   1   Median :2017   Median : 7.000   Median :16.00
#  2015-01-04:   1   Mean   :2017   Mean   : 6.524   Mean   :15.73
#  2015-01-05:   1   3rd Qu.:2018   3rd Qu.:10.000   3rd Qu.:23.00
#  2015-01-06:   1   Max.   :2019   Max.   :12.000   Max.   :31.00
#  (Other)   :1820
#       temp             dewp             slp             visib
#  Min.   :-15.00   Min.   :-23.80   Min.   : 993.8   Min.   : 1.700
#  1st Qu.: 35.73   1st Qu.: 26.50   1st Qu.:1012.3   1st Qu.: 9.000
#  Median : 51.70   Median : 40.30   Median :1016.6   Median : 9.900
#  Mean   : 51.29   Mean   : 40.27   Mean   :1016.9   Mean   : 9.129
#  3rd Qu.: 69.47   3rd Qu.: 56.80   3rd Qu.:1021.3   3rd Qu.:10.000
#  Max.   : 87.10   Max.   : 75.70   Max.   :1044.1   Max.   :10.000
#
# ...
